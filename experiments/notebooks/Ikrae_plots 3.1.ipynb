# %%
# !git clone https://github.com/karimoos/ikrae.git
# %cd ikrae
# Out:
# Cloning into 'ikrae'...
# remote: Enumerating objects: 303, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 303 (delta 65), reused 5 (delta 5), pack-reused 166 (from 1)
# Receiving objects: 100% (303/303), 1.23 MiB | 9.84 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# /content/ikrae

# %%
import os

os.makedirs("experiments/notebooks", exist_ok=True)
os.makedirs("experiments/figures", exist_ok=True)
